# %%
import numpy as np
from keras.utils import np_utils
from keras.models import Model, Sequential, load_model
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Reshape, Dropout
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.vgg16 import VGG16
# from keras.applications.resnet50 import ResNet50
from sklearn.metrics import confusion_matrix, classification_report
import itertools
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
df = pd.read_csv('frames.csv')
df.rename(columns={'Unnamed: 0': 'index',
                   '0': 'image_path'},
          inplace=True)

# %%
df
# Out:
#          index                                         image_path
# 0            0  C:\Users\sunja\OneDrive\Documents\Sem2\Big Dat...
# 1            1  C:\Users\sunja\OneDrive\Documents\Sem2\Big Dat...
# 2            2  C:\Users\sunja\OneDrive\Documents\Sem2\Big Dat...
# 3            3  C:\Users\sunja\OneDrive\Documents\Sem2\Big Dat...
# 4            4  C:\Users\sunja\OneDrive\Documents\Sem2\Big Dat...
# ...        ...                                                ...
# 495767  495767  C:\Users\sunja\OneDrive\Documents\Sem2\Big Dat...
# 495768  495768  C:\Users\sunja\OneDrive\Documents\Sem2\Big Dat...
# 495769  495769  C:\Users\sunja\OneDrive\Documents\Sem2\Big Dat...
# 495770  495770  C:\Users\sunja\OneDrive\Documents\Sem2\Big Dat...
# 495771  495771  C:\Users\sunja\OneDrive\Documents\Sem2\Big Dat...
#
# [495772 rows x 2 columns]

# %%
ids = []
for i in df['image_path']:
    ids.append(i.split('\\')[-1].split('-')[0])

df['id'] = ids
df['id'] = df['id'].astype(int)

# %%
df
# Out:
#          index                                         image_path    id
# 0            0  C:\Users\sunja\OneDrive\Documents\Sem2\Big Dat...     1
# 1            1  C:\Users\sunja\OneDrive\Documents\Sem2\Big Dat...     1
# 2            2  C:\Users\sunja\OneDrive\Documents\Sem2\Big Dat...     1
# 3            3  C:\Users\sunja\OneDrive\Documents\Sem2\Big Dat...     1
# 4            4  C:\Users\sunja\OneDrive\Documents\Sem2\Big Dat...     1
# ...        ...                                                ...   ...
# 495767  495767  C:\Users\sunja\OneDrive\Documents\Sem2\Big Dat...  6475
# 495768  495768  C:\Users\sunja\OneDrive\Documents\Sem2\Big Dat...  6475
# 495769  495769  C:\Users\sunja\OneDrive\Documents\Sem2\Big Dat...  6475
# 495770  495770  C:\Users\sunja\OneDrive\Documents\Sem2\Big Dat...  6475
# 495771  495771  C:\Users\sunja\OneDrive\Documents\Sem2\Big Dat...  6475
#
# [495772 rows x 3 columns]

# %%
model = VGG16(weights="imagenet", include_top=True, input_shape=(224, 224, 3))
out = model.layers[-2].output
model_final = Model(inputs=model.input, outputs=out)

# %%
def load_image(path):
    img = cv2.imread(path)
    img = cv2.resize(img, (224, 224))
    return img

# %%
# errors = []
# for i in range(1243,6476):
#     try:
#         n_path = os.getcwd() + '\\features\\' + str(i) + '.npy'
#         image_list = list(df['image_path'][df['id'] == i])
#         print(i, 'is running')
#         if len(image_list) == 80:
#             images = np.zeros((len(image_list), 224, 224, 3))
#             for j in range(len(image_list)):
#                 img = load_image(image_list[j])
#                 images[j] = img
#             images = np.array(images)
#             fc_feats = model_final.predict(images, batch_size=128)
#             img_feats = np.array(fc_feats)
#             np.save(n_path,img_feats)
#             print(i, 'is done')
#     except:
#         print('Error in: ', i)
#         errors.append(i)
# Out:
# 1243 is running
# 1243 is done
# 1244 is running
# 1244 is done
# 1245 is running
# 1245 is done
# 1246 is running
# 1246 is done
# 1247 is running
# 1247 is done
# 1248 is running
# 1248 is done
# 1249 is running
# 1249 is done
# 1250 is running
# 1250 is done
# 1251 is running
# 1251 is done
# 1252 is running
# 1252 is done
# 1253 is running
# 1253 is done
# 1254 is running
# 1255 is running
# 1255 is done
# 1256 is running
# 1257 is running
# 1257 is done
# 1258 is running
# 1258 is done
# 1259 is running
# 1259 is done
# 1260 is running
# 1260 is done
# 1261 is running
# 1261 is done
# 1262 is running
# 1263 is running
# 1263 is done
# 1264 is running
# 1264 is done
# 1265 is running
# 1265 is done
# 1266 is running
# 1266 is done
# 1267 is running
# 1267 is done
# 1268 is running
# 1268 is done
# 1269 is running
# 1269 is done
# 1270 is running
# 1270 is done
# 1271 is running
# 1271 is done
# 1272 is running
# 1272 is done
# 1273 is running
# 1273 is done
# 1274 is running
# 1274 is done
# 1275 is running
# 1275 is done
# 1276 is running
# 1276 is done
# 1277 is running
# 1277 is done
# 1278 is running
# 1278 is done
# 1279 is running
# 1280 is running
# 1280 is done
# 1281 is running
# 1281 is done
# 1282 is running
# 1282 is done
# 1283 is running
# 1283 is done
# 1284 is running
# 1284 is done
# 1285 is running
# 1285 is done
# 1286 is running
# 1286 is done
# 1287 is running
# 1287 is done
# 1288 is running
# 1288 is done
# 1289 is running
# 1289 is done
# 1290 is running
# 1290 is done
# 1291 is running
# 1291 is done
# 1292 is running
# 1292 is done
# 1293 is running
# 1293 is done
# 1294 is running
# 1294 is done
# 1295 is running
# 1295 is done
# 1296 is running
# 1297 is running
# 1297 is done
# 1298 is running
# 1298 is done
# 1299 is running
# 1299 is done
# 1300 is running
# 1300 is done
# 1301 is running
# 1302 is running
# 1302 is done
# 1303 is running
# 1303 is done
# 1304 is running
# 1304 is done
# 1305 is running
# 1305 is done
# 1306 is running
# 1306 is done
# 1307 is running
# 1307 is done
# 1308 is running
# 1308 is done
# 1309 is running
# 1309 is done
# 1310 is running
# 1310 is done
# 1311 is running
# 1311 is done
# 1312 is running
# 1312 is done
# 1313 is running
# 1313 is done
# 1314 is running
# 1314 is done
# 1315 is running
# 1315 is done
# 1316 is running
# 1316 is done
# 1317 is running
# 1317 is done
# 1318 is running
# 1318 is done
# 1319 is running
# 1319 is done
# 1320 is running
# 1320 is done
# 1321 is running
# 1321 is done
# 1322 is running
# 1322 is done
# 1323 is running
# 1323 is done
# 1324 is running
# 1324 is done
# 1325 is running
# 1325 is done
# 1326 is running
# 1326 is done
# 1327 is running
# 1327 is done
# 1328 is running
# 1328 is done
# 1329 is running
# 1330 is running
# 1330 is done
# 1331 is running
# 1331 is done
# 1332 is running
# 1332 is done
# 1333 is running
# 1333 is done
# 1334 is running
# 1335 is running
# 1335 is done
# 1336 is running
# 1336 is done
# 1337 is running
# 1337 is done
# 1338 is running
# 1338 is done
# 1339 is running
# 1339 is done
# 1340 is running
# 1340 is done
# 1341 is running
# 1341 is done
# 1342 is running
# 1342 is done
# 1343 is running
# 1343 is done
# 1344 is running
# 1344 is done
# 1345 is running
# 1345 is done
# 1346 is running
# 1346 is done
# 1347 is running
# 1347 is done
# 1348 is running
# 1349 is running
# 1349 is done
# 1350 is running
# 1350 is done
# 1351 is running
# 1351 is done
# 1352 is running
# 1352 is done
# 1353 is running
# 1353 is done
# 1354 is running
# 1354 is done
# 1355 is running
# 1355 is done
# 1356 is running
# 1356 is done
# 1357 is running
# 1357 is done
# 1358 is running
# 1358 is done
# 1359 is running
# 1359 is done
# 1360 is running
# 1360 is done
# 1361 is running
# 1361 is done
# 1362 is running
# 1362 is done
# 1363 is running
# 1363 is done
# 1364 is running
# 1364 is done
# 1365 is running
# 1365 is done
# 1366 is running
# 1366 is done
# 1367 is running
# 1367 is done
# 1368 is running
# 1368 is done
# 1369 is running
# 1369 is done
# 1370 is running
# 1370 is done
# 1371 is running
# 1371 is done
# 1372 is running
# 1372 is done
# 1373 is running
# 1373 is done
# 1374 is running
# 1374 is done
# 1375 is running
# 1375 is done
# 1376 is running
# 1376 is done
# 1377 is running
# 1378 is running
# 1378 is done
# 1379 is running
# 1379 is done
# 1380 is running
# 1380 is done
# 1381 is running
# 1381 is done
# 1382 is running
# 1382 is done
# 1383 is running
# 1383 is done
# 1384 is running
# 1384 is done
# 1385 is running
# 1385 is done
# 1386 is running
# 1386 is done
# 1387 is running
# 1387 is done
# 1388 is running
# 1388 is done
# 1389 is running
# 1389 is done
# 1390 is running
# 1390 is done
# 1391 is running
# 1391 is done
# 1392 is running
# 1392 is done
# 1393 is running
# 1393 is done
# 1394 is running
# 1394 is done
# 1395 is running
# 1395 is done
# 1396 is running
# 1396 is done
# 1397 is running
# 1397 is done
# 1398 is running
# 1398 is done
# 1399 is running
# 1399 is done
# 1400 is running
# 1401 is running
# 1401 is done
# 1402 is running
# 1402 is done
# 1403 is running
# 1404 is running
# 1404 is done
# 1405 is running
# 1405 is done
# 1406 is running
# 1407 is running
# 1408 is running
# 1408 is done
# 1409 is running
# 1409 is done
# 1410 is running
# 1410 is done
# 1411 is running
# 1411 is done
# 1412 is running
# 1412 is done
# 1413 is running
# 1413 is done
# 1414 is running
# 1414 is done
# 1415 is running
# 1415 is done
# 1416 is running
# 1416 is done
# 1417 is running
# 1417 is done
# 1418 is running
# 1418 is done
# 1419 is running
# 1419 is done
# 1420 is running
# 1420 is done
# 1421 is running
# 1421 is done
# 1422 is running
# 1422 is done
# 1423 is running
# 1423 is done
# 1424 is running
# 1424 is done
# 1425 is running
# 1425 is done
# 1426 is running
# 1426 is done
# 1427 is running
# 1427 is done
# 1428 is running
# 1428 is done
# 1429 is running
# 1429 is done
# 1430 is running
# 1430 is done
# 1431 is running
# 1432 is running
# 1432 is done
# 1433 is running
# 1433 is done
# 1434 is running
# 1435 is running
# 1435 is done
# 1436 is running
# 1436 is done
# 1437 is running
# 1437 is done
# 1438 is running
# 1438 is done
# 1439 is running
# 1439 is done
# 1440 is running
# 1441 is running
# 1441 is done
# 1442 is running
# 1442 is done
# 1443 is running
# 1443 is done
# 1444 is running
# 1444 is done
# 1445 is running
# 1445 is done
# 1446 is running
# 1446 is done
# 1447 is running
# 1447 is done
# 1448 is running
# 1448 is done
# 1449 is running
# 1449 is done
# 1450 is running
# 1450 is done
# 1451 is running
# 1451 is done
# 1452 is running
# 1452 is done
# 1453 is running
# 1453 is done
# 1454 is running
# 1454 is done
# 1455 is running
# 1456 is running
# 1456 is done
# 1457 is running
# 1457 is done
# 1458 is running
# 1458 is done
# 1459 is running
# 1459 is done
# 1460 is running
# 1460 is done
# 1461 is running
# 1461 is done
# 1462 is running
# 1462 is done
# 1463 is running
# 1463 is done
# 1464 is running
# 1465 is running
# 1465 is done
# 1466 is running
# 1466 is done
# 1467 is running
# 1467 is done
# 1468 is running
# 1468 is done
# 1469 is running
# 1469 is done
# 1470 is running
# 1470 is done
# 1471 is running
# 1471 is done
# 1472 is running
# 1472 is done
# 1473 is running
# 1473 is done
# 1474 is running
# 1474 is done
# 1475 is running
# 1475 is done
# 1476 is running
# 1476 is done
# 1477 is running
# 1477 is done
# 1478 is running
# 1478 is done
# 1479 is running
# 1479 is done
# 1480 is running
# 1480 is done
# 1481 is running
# 1481 is done
# 1482 is running
# 1482 is done
# 1483 is running
# 1483 is done
# 1484 is running
# 1484 is done
# 1485 is running
# 1486 is running
# 1486 is done
# 1487 is running
# 1487 is done
# 1488 is running
# 1488 is done
# 1489 is running
# 1489 is done
# 1490 is running
# 1490 is done
# 1491 is running
# 1491 is done
# 1492 is running
# 1492 is done
# 1493 is running
# 1493 is done
# 1494 is running
# 1494 is done
# 1495 is running
# 1496 is running
# 1496 is done
# 1497 is running
# 1497 is done
# 1498 is running
# 1498 is done
# 1499 is running
# 1499 is done
# 1500 is running
# 1500 is done
# 1501 is running
# 1501 is done
# 1502 is running
# 1502 is done
# 1503 is running
# 1503 is done
# 1504 is running
# 1504 is done
# 1505 is running
# 1506 is running
# 1506 is done
# 1507 is running
# 1507 is done
# 1508 is running
# 1508 is done
# 1509 is running
# 1509 is done
# 1510 is running
# 1511 is running
# 1511 is done
# 1512 is running
# 1512 is done
# 1513 is running
# 1513 is done
# 1514 is running
# 1514 is done
# 1515 is running
# 1515 is done
# 1516 is running
# 1516 is done
# 1517 is running
# 1517 is done
# 1518 is running
# 1518 is done
# 1519 is running
# 1520 is running
# 1520 is done
# 1521 is running
# 1521 is done
# 1522 is running
# 1522 is done
# 1523 is running
# 1523 is done
# 1524 is running
# 1525 is running
# 1525 is done
# 1526 is running
# 1526 is done
# 1527 is running
# 1527 is done
# 1528 is running
# 1528 is done
# 1529 is running
# 1529 is done
# 1530 is running
# 1530 is done
# 1531 is running
# 1531 is done
# 1532 is running
# 1533 is running
# 1533 is done
# 1534 is running
# 1535 is running
# 1535 is done
# 1536 is running
# 1536 is done
# 1537 is running
# 1537 is done
# 1538 is running
# 1538 is done
# 1539 is running
# 1539 is done
# 1540 is running
# 1540 is done
# 1541 is running
# 1542 is running
# 1542 is done
# 1543 is running
# 1543 is done
# 1544 is running
# 1545 is running
# 1545 is done
# 1546 is running
# 1546 is done
# 1547 is running
# 1547 is done
# 1548 is running
# 1548 is done
# 1549 is running
# 1549 is done
# 1550 is running
# 1550 is done
# 1551 is running
# 1551 is done
# 1552 is running
# 1552 is done
# 1553 is running
# 1553 is done
# 1554 is running
# 1555 is running
# 1555 is done
# 1556 is running
# 1556 is done
# 1557 is running
# 1557 is done
# 1558 is running
# 1558 is done
# 1559 is running
# 1559 is done
# 1560 is running
# 1560 is done
# 1561 is running
# 1561 is done
# 1562 is running
# 1562 is done
# 1563 is running
# 1563 is done
# 1564 is running
# 1564 is done
# 1565 is running
# 1565 is done
# 1566 is running
# 1566 is done
# 1567 is running
# 1567 is done
# 1568 is running
# 1569 is running
# 1569 is done
# 1570 is running
# 1570 is done
# 1571 is running
# 1571 is done
# 1572 is running
# 1572 is done
# 1573 is running
# 1573 is done
# 1574 is running
# 1574 is done
# 1575 is running
# 1576 is running
# 1576 is done
# 1577 is running
# 1577 is done
# 1578 is running
# 1578 is done
# 1579 is running
# 1579 is done
# 1580 is running
# 1580 is done
# 1581 is running
# 1581 is done
# 1582 is running
# 1582 is done
# 1583 is running
# 1583 is done
# 1584 is running
# 1584 is done
# 1585 is running
# 1585 is done
# 1586 is running
# 1586 is done
# 1587 is running
# 1587 is done
# 1588 is running
# 1588 is done
# 1589 is running
# 1589 is done
# 1590 is running
# 1590 is done
# 1591 is running
# 1591 is done
# 1592 is running
# 1592 is done
# 1593 is running
# 1593 is done
# 1594 is running
# 1594 is done
# 1595 is running
# 1595 is done
# 1596 is running
# 1596 is done
# 1597 is running
# 1597 is done
# 1598 is running
# 1598 is done
# 1599 is running
# 1599 is done
# 1600 is running
# 1600 is done
# 1601 is running
# 1601 is done
# 1602 is running
# 1602 is done
# 1603 is running
# 1603 is done
# 1604 is running
# 1604 is done
# 1605 is running
# 1605 is done
# 1606 is running
# 1606 is done
# 1607 is running
# 1607 is done
# 1608 is running
# 1608 is done
# 1609 is running
# 1609 is done
# 1610 is running
# 1610 is done
# 1611 is running
# 1611 is done
# 1612 is running
# 1612 is done
# 1613 is running
# 1613 is done
# 1614 is running
# 1614 is done
# 1615 is running
# 1615 is done
# 1616 is running
# 1616 is done
# 1617 is running
# 1617 is done
# 1618 is running
# 1619 is running
# 1619 is done
# 1620 is running
# 1620 is done
# 1621 is running
# 1621 is done
# 1622 is running
# 1622 is done
# 1623 is running
# 1623 is done
# 1624 is running
# 1624 is done
# 1625 is running
# 1625 is done
# 1626 is running
# 1626 is done
# 1627 is running
# 1627 is done
# 1628 is running
# 1628 is done
# 1629 is running
# 1629 is done
# 1630 is running
# 1630 is done
# 1631 is running
# 1631 is done
# 1632 is running
# 1632 is done
# 1633 is running
# 1633 is done
# 1634 is running
# 1634 is done
# 1635 is running
# 1635 is done
# 1636 is running
# 1637 is running
# 1637 is done
# 1638 is running
# 1638 is done
# 1639 is running
# 1639 is done
# 1640 is running
# 1640 is done
# 1641 is running
# 1641 is done
# 1642 is running
# 1643 is running
# 1643 is done
# 1644 is running
# 1644 is done
# 1645 is running
# 1645 is done
# 1646 is running
# 1646 is done
# 1647 is running
# 1647 is done
# 1648 is running
# 1648 is done
# 1649 is running
# 1649 is done
# 1650 is running
# 1651 is running
# 1651 is done
# 1652 is running
# 1652 is done
# 1653 is running
# 1653 is done
# 1654 is running
# 1655 is running
# 1655 is done
# 1656 is running
# 1656 is done
# 1657 is running
# 1658 is running
# 1658 is done
# 1659 is running
# 1659 is done
# 1660 is running
# 1660 is done
# 1661 is running
# 1661 is done
# 1662 is running
# 1662 is done
# 1663 is running
# 1663 is done
# 1664 is running
# 1664 is done
# 1665 is running
# 1666 is running
# 1666 is done
# 1667 is running
# 1668 is running
# 1668 is done
# 1669 is running
# 1669 is done
# 1670 is running
# 1670 is done
# 1671 is running
# 1671 is done
# 1672 is running
# 1672 is done
# 1673 is running
# 1673 is done
# 1674 is running
# 1675 is running
# 1675 is done
# 1676 is running
# 1676 is done
# 1677 is running
# 1677 is done
# 1678 is running
# 1678 is done
# 1679 is running
# 1679 is done
# 1680 is running
# 1680 is done
# 1681 is running
# 1681 is done
# 1682 is running
# 1682 is done
# 1683 is running
# 1683 is done
# 1684 is running
# 1684 is done
# 1685 is running
# 1685 is done
# 1686 is running
# 1686 is done
# 1687 is running
# 1687 is done
# 1688 is running
# 1688 is done
# 1689 is running
# 1689 is done
# 1690 is running
# 1690 is done
# 1691 is running
# 1691 is done
# 1692 is running
# 1693 is running
# 1693 is done
# 1694 is running
# 1694 is done
# 1695 is running
# 1695 is done
# 1696 is running
# 1696 is done
# 1697 is running
# 1697 is done
# 1698 is running
# 1698 is done
# 1699 is running
# 1699 is done
# 1700 is running
# 1700 is done
# 1701 is running
# 1701 is done
# 1702 is running
# 1702 is done
# 1703 is running
# 1703 is done
# 1704 is running
# 1704 is done
# 1705 is running
# 1705 is done
# 1706 is running
# 1706 is done
# 1707 is running
# 1707 is done
# 1708 is running
# 1709 is running
# 1709 is done
# 1710 is running
# 1710 is done
# 1711 is running
# 1711 is done
# 1712 is running
# 1712 is done
# 1713 is running
# 1713 is done
# 1714 is running
# 1715 is running
# 1715 is done
# 1716 is running
# 1716 is done
# 1717 is running
# 1717 is done
# 1718 is running
# 1718 is done
# 1719 is running
# 1719 is done
# 1720 is running
# 1720 is done
# 1721 is running
# 1721 is done
# 1722 is running
# 1722 is done
# 1723 is running
# 1723 is done
# 1724 is running
# 1725 is running
# 1726 is running
# 1726 is done
# 1727 is running
# 1727 is done
# 1728 is running
# 1729 is running
# 1729 is done
# 1730 is running
# 1731 is running
# 1731 is done
# 1732 is running
# 1732 is done
# 1733 is running
# 1733 is done
# 1734 is running
# 1734 is done
# 1735 is running
# 1735 is done
# 1736 is running
# 1736 is done
# 1737 is running
# 1737 is done
# 1738 is running
# 1738 is done
# 1739 is running
# 1739 is done
# 1740 is running
# 1740 is done
# 1741 is running
# 1741 is done
# 1742 is running
# 1742 is done
# 1743 is running
# 1743 is done
# 1744 is running
# 1744 is done
# 1745 is running
# 1745 is done
# 1746 is running
# 1746 is done
# 1747 is running
# 1747 is done
# 1748 is running
# 1748 is done
# 1749 is running
# 1749 is done
# 1750 is running
# 1750 is done
# 1751 is running
# 1751 is done
# 1752 is running
# 1752 is done
# 1753 is running
# 1753 is done
# 1754 is running
# 1754 is done
# 1755 is running
# 1755 is done
# 1756 is running
# 1756 is done
# 1757 is running
# 1758 is running
# 1758 is done
# 1759 is running
# 1759 is done
# 1760 is running
# 1760 is done
# 1761 is running
# 1761 is done
# 1762 is running
# 1762 is done
# 1763 is running
# 1763 is done
# 1764 is running
# 1764 is done
# 1765 is running
# 1765 is done
# 1766 is running
# 1766 is done
# 1767 is running
# 1767 is done
# 1768 is running
# 1768 is done
# 1769 is running
# 1769 is done
# 1770 is running
# 1770 is done
# 1771 is running
# 1771 is done
# 1772 is running
# 1772 is done
# 1773 is running
# 1773 is done
# 1774 is running
# 1775 is running
# 1775 is done
# 1776 is running
# 1776 is done
# 1777 is running
# 1777 is done
# 1778 is running
# 1778 is done
# 1779 is running
# 1779 is done
# 1780 is running
# 1780 is done
# 1781 is running
# 1781 is done
# 1782 is running
# 1782 is done
# 1783 is running
# 1783 is done
# 1784 is running
# 1784 is done
# 1785 is running
# 1785 is done
# 1786 is running
# 1786 is done
# 1787 is running
# 1787 is done
# 1788 is running
# 1788 is done
# 1789 is running
# 1789 is done
# 1790 is running
# 1790 is done
# 1791 is running
# 1791 is done
# 1792 is running
# 1792 is done
# 1793 is running
# 1793 is done
# 1794 is running
# 1794 is done
# 1795 is running
# 1796 is running
# 1797 is running
# 1797 is done
# 1798 is running
# 1798 is done
# 1799 is running
# 1799 is done
# 1800 is running
# 1800 is done
# 1801 is running
# 1801 is done
# 1802 is running
# 1802 is done
# 1803 is running
# 1804 is running
# 1804 is done
# 1805 is running
# 1805 is done
# 1806 is running
# 1806 is done
# 1807 is running
# 1807 is done
# 1808 is running
# 1808 is done
# 1809 is running
# 1809 is done
# 1810 is running
# 1810 is done
# 1811 is running
# 1811 is done
# 1812 is running
# 1812 is done
# 1813 is running
# 1813 is done
# 1814 is running
# 1814 is done
# 1815 is running
# 1815 is done
# 1816 is running
# 1816 is done
# 1817 is running
# 1817 is done
# 1818 is running
# 1818 is done
# 1819 is running
# 1819 is done
# 1820 is running
# 1820 is done
# 1821 is running
# 1821 is done
# 1822 is running
# 1823 is running
# 1824 is running
# 1824 is done
# 1825 is running
# 1825 is done
# 1826 is running
# 1826 is done
# 1827 is running
# 1827 is done
# 1828 is running
# 1828 is done
# 1829 is running
# 1829 is done
# 1830 is running
# 1830 is done
# 1831 is running
# 1831 is done
# 1832 is running
# 1832 is done
# 1833 is running
# 1833 is done
# 1834 is running
# 1834 is done
# 1835 is running
# 1835 is done
# 1836 is running
# 1836 is done
# 1837 is running
# 1837 is done
# 1838 is running
# 1838 is done
# 1839 is running
# 1839 is done
# 1840 is running
# 1840 is done
# 1841 is running
# 1841 is done
# 1842 is running
# 1842 is done
# 1843 is running
# 1843 is done
# 1844 is running
# 1844 is done
# 1845 is running
# 1845 is done
# 1846 is running
# 1847 is running
# 1847 is done
# 1848 is running
# 1849 is running
# 1849 is done
# 1850 is running
# 1850 is done
# 1851 is running
# 1851 is done
# 1852 is running
# 1852 is done
# 1853 is running
# 1853 is done
# 1854 is running
# 1854 is done
# 1855 is running
# 1855 is done
# 1856 is running
# 1856 is done
# 1857 is running
# 1857 is done
# 1858 is running
# 1858 is done
# 1859 is running
# 1859 is done
# 1860 is running
# 1860 is done
# 1861 is running
# 1861 is done
# 1862 is running
# 1862 is done
# 1863 is running
# 1863 is done
# 1864 is running
# 1864 is done
# 1865 is running
# 1865 is done
# 1866 is running
# 1867 is running
# 1867 is done
# 1868 is running
# 1868 is done
# 1869 is running
# 1869 is done
# 1870 is running
# 1870 is done
# 1871 is running
# 1871 is done
# 1872 is running
# 1872 is done
# 1873 is running
# 1873 is done
# 1874 is running
# 1874 is done
# 1875 is running
# 1875 is done
# 1876 is running
# 1876 is done
# 1877 is running
# 1877 is done
# 1878 is running
# 1878 is done
# 1879 is running
# 1879 is done
# 1880 is running
# 1880 is done
# 1881 is running
# 1881 is done
# 1882 is running
# 1882 is done
# 1883 is running
# 1884 is running
# 1884 is done
# 1885 is running
# 1885 is done
# 1886 is running
# 1886 is done
# 1887 is running
# 1887 is done
# 1888 is running
# 1889 is running
# 1889 is done
# 1890 is running
# 1890 is done
# 1891 is running
# 1891 is done
# 1892 is running
# 1892 is done
# 1893 is running
# 1893 is done
# 1894 is running
# 1894 is done
# 1895 is running
# 1895 is done
# 1896 is running
# 1896 is done
# 1897 is running
# 1897 is done
# 1898 is running
# 1898 is done
# 1899 is running
# 1899 is done
# 1900 is running
# 1900 is done
# 1901 is running
# 1901 is done
# 1902 is running
# 1902 is done
# 1903 is running
# 1903 is done
# 1904 is running
# 1904 is done
# 1905 is running
# 1905 is done
# 1906 is running
# 1906 is done
# 1907 is running
# 1908 is running
# 1908 is done
# 1909 is running
# 1909 is done
# 1910 is running
# 1910 is done
# 1911 is running
# 1911 is done
# 1912 is running
# 1913 is running
# 1913 is done
# 1914 is running
# 1914 is done
# 1915 is running
# 1915 is done
# 1916 is running
# 1916 is done
# 1917 is running
# 1917 is done
# 1918 is running
# 1918 is done
# 1919 is running
# 1919 is done
# 1920 is running
# 1920 is done
# 1921 is running
# 1921 is done
# 1922 is running
# 1922 is done
# 1923 is running
# 1923 is done
# 1924 is running
# 1924 is done
# 1925 is running
# 1925 is done
# 1926 is running
# 1926 is done
# 1927 is running
# 1927 is done
# 1928 is running
# 1928 is done
# 1929 is running
# 1929 is done
# 1930 is running
# 1930 is done
# 1931 is running
# 1931 is done
# 1932 is running
# 1932 is done
# 1933 is running
# 1933 is done
# 1934 is running
# 1935 is running
# 1935 is done
# 1936 is running
# 1936 is done
# 1937 is running
# 1937 is done
# 1938 is running
# 1939 is running
# 1939 is done
# 1940 is running
# 1940 is done
# 1941 is running
# 1941 is done
# 1942 is running
# 1943 is running
# 1943 is done
# 1944 is running
# 1944 is done
# 1945 is running
# 1945 is done
# 1946 is running
# 1946 is done
# 1947 is running
# 1947 is done
# 1948 is running
# 1948 is done
# 1949 is running
# 1949 is done
# 1950 is running
# 1950 is done
# 1951 is running
# 1951 is done
# 1952 is running
# 1952 is done
# 1953 is running
# 1954 is running
# 1954 is done
# 1955 is running
# 1955 is done
# 1956 is running
# 1956 is done
# 1957 is running
# 1958 is running
# 1958 is done
# 1959 is running
# 1959 is done
# 1960 is running
# 1960 is done
# 1961 is running
# 1961 is done
# 1962 is running
# 1962 is done
# 1963 is running
# 1963 is done
# 1964 is running
# 1964 is done
# 1965 is running
# 1965 is done
# 1966 is running
# 1966 is done
# 1967 is running
# 1967 is done
# 1968 is running
# 1968 is done
# 1969 is running
# 1969 is done
# 1970 is running
# 1970 is done
# 1971 is running
# 1971 is done
# 1972 is running
# 1972 is done
# 1973 is running
# 1973 is done
# 1974 is running
# 1974 is done
# 1975 is running
# 1975 is done
# 1976 is running
# 1976 is done
# 1977 is running
# 1977 is done
# 1978 is running
# 1978 is done
# 1979 is running
# 1979 is done
# 1980 is running
# 1980 is done
# 1981 is running
# 1981 is done
# 1982 is running
# 1982 is done
# 1983 is running
# 1984 is running
# 1984 is done
# 1985 is running
# 1985 is done
# 1986 is running
# 1986 is done
# 1987 is running
# 1988 is running
# 1988 is done
# 1989 is running
# 1989 is done
# 1990 is running
# 1990 is done
# 1991 is running
# 1991 is done
# 1992 is running
# 1992 is done
# 1993 is running
# 1993 is done
# 1994 is running
# 1994 is done
# 1995 is running
# 1995 is done
# 1996 is running
# 1996 is done
# 1997 is running
# 1997 is done
# 1998 is running
# 1998 is done
# 1999 is running
# 1999 is done
# 2000 is running
# 2000 is done
# 2001 is running
# 2001 is done
# 2002 is running
# 2002 is done
# 2003 is running
# 2003 is done
# 2004 is running
# 2004 is done
# 2005 is running
# 2005 is done
# 2006 is running
# 2006 is done
# 2007 is running
# 2007 is done
# 2008 is running
# 2008 is done
# 2009 is running
# 2009 is done
# 2010 is running
# 2010 is done
# 2011 is running
# 2011 is done
# 2012 is running
# 2012 is done
# 2013 is running
# 2013 is done
# 2014 is running
# 2014 is done
# 2015 is running
# 2015 is done
# 2016 is running
# 2017 is running
# 2017 is done
# 2018 is running
# 2018 is done
# 2019 is running
# 2019 is done
# 2020 is running
# 2020 is done
# 2021 is running
# 2021 is done
# 2022 is running
# 2022 is done
# 2023 is running
# 2023 is done
# 2024 is running
# 2024 is done
# 2025 is running
# 2025 is done
# 2026 is running
# 2026 is done
# 2027 is running
# 2027 is done
# 2028 is running
# 2028 is done
# 2029 is running
# 2029 is done
# 2030 is running
# 2030 is done
# 2031 is running
# 2031 is done
# 2032 is running
# 2032 is done
# 2033 is running
# 2033 is done
# 2034 is running
# 2034 is done
# 2035 is running
# 2035 is done
# 2036 is running
# 2036 is done
# 2037 is running
# 2037 is done
# 2038 is running
# 2038 is done
# 2039 is running
# 2040 is running
# 2040 is done
# 2041 is running
# 2041 is done
# 2042 is running
# 2042 is done
# 2043 is running
# 2043 is done
# 2044 is running
# 2044 is done
# 2045 is running
# 2045 is done
# 2046 is running
# 2046 is done
# 2047 is running
# 2047 is done
# 2048 is running
# 2048 is done
# 2049 is running
# 2049 is done
# 2050 is running
# 2050 is done
# 2051 is running
# 2051 is done
# 2052 is running
# 2052 is done
# 2053 is running
# 2053 is done
# 2054 is running
# 2054 is done
# 2055 is running
# 2055 is done
# 2056 is running
# 2056 is done
# 2057 is running
# 2057 is done
# 2058 is running
# 2058 is done
# 2059 is running
# 2059 is done
# 2060 is running
# 2060 is done
# 2061 is running
# 2061 is done
# 2062 is running
# 2062 is done
# 2063 is running
# 2063 is done
# 2064 is running
# 2064 is done
# 2065 is running
# 2065 is done
# 2066 is running
# 2066 is done
# 2067 is running
# 2067 is done
# 2068 is running
# 2068 is done
# 2069 is running
# 2069 is done
# 2070 is running
# 2070 is done
# 2071 is running
# 2072 is running
# 2072 is done
# 2073 is running
# 2073 is done
# 2074 is running
# 2074 is done
# 2075 is running
# 2075 is done
# 2076 is running
# 2076 is done
# 2077 is running
# 2078 is running
# 2079 is running
# 2079 is done
# 2080 is running
# 2081 is running
# 2081 is done
# 2082 is running
# 2082 is done
# 2083 is running
# 2083 is done
# 2084 is running
# 2084 is done
# 2085 is running
# 2086 is running
# 2086 is done
# 2087 is running
# 2087 is done
# 2088 is running
# 2088 is done
# 2089 is running
# 2089 is done
# 2090 is running
# 2090 is done
# 2091 is running
# 2091 is done
# 2092 is running
# 2092 is done
# 2093 is running
# 2093 is done
# 2094 is running
# 2094 is done
# 2095 is running
# 2095 is done
# 2096 is running
# 2096 is done
# 2097 is running
# 2097 is done
# 2098 is running
# 2098 is done
# 2099 is running
# 2099 is done
# 2100 is running
# 2100 is done
# 2101 is running
# 2101 is done
# 2102 is running
# 2102 is done
# 2103 is running
# 2103 is done
# 2104 is running
# 2104 is done
# 2105 is running
# 2106 is running
# 2106 is done
# 2107 is running
# 2107 is done
# 2108 is running
# 2108 is done
# 2109 is running
# 2109 is done
# 2110 is running
# 2110 is done
# 2111 is running
# 2111 is done
# 2112 is running
# 2113 is running
# 2113 is done
# 2114 is running
# 2114 is done
# 2115 is running
# 2115 is done
# 2116 is running
# 2117 is running
# 2117 is done
# 2118 is running
# 2118 is done
# 2119 is running
# 2119 is done
# 2120 is running
# 2120 is done
# 2121 is running
# 2121 is done
# 2122 is running
# 2122 is done
# 2123 is running
# 2123 is done
# 2124 is running
# 2125 is running
# 2125 is done
# 2126 is running
# 2126 is done
# 2127 is running
# 2127 is done
# 2128 is running
# 2128 is done
# 2129 is running
# 2129 is done
# 2130 is running
# 2130 is done
# 2131 is running
# 2131 is done
# 2132 is running
# 2132 is done
# 2133 is running
# 2133 is done
# 2134 is running
# 2134 is done
# 2135 is running
# 2135 is done
# 2136 is running
# 2136 is done
# 2137 is running
# 2137 is done
# 2138 is running
# 2138 is done
# 2139 is running
# 2139 is done
# 2140 is running
# 2140 is done
# 2141 is running
# 2141 is done
# 2142 is running
# 2142 is done
# 2143 is running
# 2144 is running
# 2144 is done
# 2145 is running
# 2145 is done
# 2146 is running
# 2147 is running
# 2147 is done
# 2148 is running
# 2148 is done
# 2149 is running
# 2149 is done
# 2150 is running
# 2151 is running
# 2151 is done
# 2152 is running
# 2152 is done
# 2153 is running
# 2153 is done
# 2154 is running
# 2154 is done
# 2155 is running
# 2155 is done
# 2156 is running
# 2156 is done
# 2157 is running
# 2157 is done
# 2158 is running
# 2158 is done
# 2159 is running
# 2159 is done
# 2160 is running
# 2160 is done
# 2161 is running
# 2161 is done
# 2162 is running
# 2162 is done
# 2163 is running
# 2163 is done
# 2164 is running
# 2165 is running
# 2165 is done
# 2166 is running
# 2166 is done
# 2167 is running
# 2167 is done
# 2168 is running
# 2168 is done
# 2169 is running
# 2169 is done
# 2170 is running
# 2170 is done
# 2171 is running
# 2172 is running
# 2172 is done
# 2173 is running
# 2173 is done
# 2174 is running
# 2174 is done
# 2175 is running
# 2175 is done
# 2176 is running
# 2176 is done
# 2177 is running
# 2177 is done
# 2178 is running
# 2178 is done
# 2179 is running
# 2179 is done
# 2180 is running
# 2180 is done
# 2181 is running
# 2181 is done
# 2182 is running
# 2182 is done
# 2183 is running
# 2183 is done
# 2184 is running
# 2184 is done
# 2185 is running
# 2185 is done
# 2186 is running
# 2186 is done
# 2187 is running
# 2187 is done
# 2188 is running
# 2188 is done
# 2189 is running
# 2189 is done
# 2190 is running
# 2191 is running
# 2191 is done
# 2192 is running
# 2192 is done
# 2193 is running
# 2193 is done
# 2194 is running
# 2194 is done
# 2195 is running
# 2195 is done
# 2196 is running
# 2196 is done
# 2197 is running
# 2197 is done
# 2198 is running
# 2198 is done
# 2199 is running
# 2199 is done
# 2200 is running
# 2200 is done
# 2201 is running
# 2201 is done
# 2202 is running
# 2202 is done
# 2203 is running
# 2203 is done
# 2204 is running
# 2204 is done
# 2205 is running
# 2205 is done
# 2206 is running
# 2206 is done
# 2207 is running
# 2208 is running
# 2208 is done
# 2209 is running
# 2209 is done
# 2210 is running
# 2210 is done
# 2211 is running
# 2211 is done
# 2212 is running
# 2212 is done
# 2213 is running
# 2213 is done
# 2214 is running
# 2214 is done
# 2215 is running
# 2215 is done
# 2216 is running
# 2216 is done
# 2217 is running
# 2217 is done
# 2218 is running
# 2218 is done
# 2219 is running
# 2219 is done
# 2220 is running
# 2220 is done
# 2221 is running
# 2221 is done
# 2222 is running
# 2222 is done
# 2223 is running
# 2223 is done
# 2224 is running
# 2224 is done
# 2225 is running
# 2225 is done
# 2226 is running
# 2226 is done
# 2227 is running
# 2227 is done
# 2228 is running
# 2228 is done
# 2229 is running
# 2229 is done
# 2230 is running
# 2230 is done
# 2231 is running
# 2231 is done
# 2232 is running
# 2232 is done
# 2233 is running
# 2233 is done
# 2234 is running
# 2234 is done
# 2235 is running
# 2235 is done
# 2236 is running
# 2236 is done
# 2237 is running
# 2237 is done
# 2238 is running
# 2238 is done
# 2239 is running
# 2239 is done
# 2240 is running
# 2240 is done
# 2241 is running
# 2241 is done
# 2242 is running
# 2242 is done
# 2243 is running
# 2243 is done
# 2244 is running
# 2244 is done
# 2245 is running
# 2245 is done
# 2246 is running
# 2246 is done
# 2247 is running
# 2248 is running
# 2249 is running
# 2249 is done
# 2250 is running
# 2250 is done
# 2251 is running
# 2251 is done
# 2252 is running
# 2252 is done
# 2253 is running
# 2254 is running
# 2254 is done
# 2255 is running
# 2255 is done
# 2256 is running
# 2256 is done
# 2257 is running
# 2257 is done
# 2258 is running
# 2258 is done
# 2259 is running
# 2259 is done
# 2260 is running
# 2260 is done
# 2261 is running
# 2261 is done
# 2262 is running
# 2262 is done
# 2263 is running
# 2263 is done
# 2264 is running
# 2265 is running
# 2265 is done
# 2266 is running
# 2266 is done
# 2267 is running
# 2267 is done
# 2268 is running
# 2268 is done
# 2269 is running
# 2269 is done
# 2270 is running
# 2270 is done
# 2271 is running
# 2271 is done
# 2272 is running
# 2272 is done
# 2273 is running
# 2273 is done
# 2274 is running
# 2275 is running
# 2275 is done
# 2276 is running
# 2276 is done
# 2277 is running
# 2277 is done
# 2278 is running
# 2278 is done
# 2279 is running
# 2279 is done
# 2280 is running
# 2280 is done
# 2281 is running
# 2281 is done
# 2282 is running
# 2282 is done
# 2283 is running
# 2283 is done
# 2284 is running
# 2284 is done
# 2285 is running
# 2285 is done
# 2286 is running
# 2286 is done
# 2287 is running
# 2288 is running
# 2288 is done
# 2289 is running
# 2289 is done
# 2290 is running
# 2290 is done
# 2291 is running
# 2291 is done
# 2292 is running
# 2292 is done
# 2293 is running
# 2293 is done
# 2294 is running
# 2294 is done
# 2295 is running
# 2295 is done
# 2296 is running
# 2296 is done
# 2297 is running
# 2297 is done
# 2298 is running
# 2298 is done
# 2299 is running
# 2299 is done
# 2300 is running
# 2300 is done
# 2301 is running
# 2301 is done
# 2302 is running
# 2302 is done
# 2303 is running
# 2303 is done
# 2304 is running
# 2304 is done
# 2305 is running
# 2305 is done
# 2306 is running
# 2306 is done
# 2307 is running
# 2307 is done
# 2308 is running
# 2308 is done
# 2309 is running
# 2309 is done
# 2310 is running
# 2310 is done
# 2311 is running
# 2311 is done
# 2312 is running
# 2312 is done
# 2313 is running
# 2313 is done
# 2314 is running
# 2314 is done
# 2315 is running
# 2315 is done
# 2316 is running
# 2316 is done
# 2317 is running
# 2317 is done
# 2318 is running
# 2318 is done
# 2319 is running
# 2319 is done
# 2320 is running
# 2320 is done
# 2321 is running
# 2321 is done
# 2322 is running
# 2322 is done
# 2323 is running
# 2323 is done
# 2324 is running
# 2324 is done
# 2325 is running
# 2325 is done
# 2326 is running
# 2326 is done
# 2327 is running
# 2327 is done
# 2328 is running
# 2328 is done
# 2329 is running
# 2329 is done
# 2330 is running
# 2330 is done
# 2331 is running
# 2331 is done
# 2332 is running
# 2332 is done
# 2333 is running
# 2333 is done
# 2334 is running
# 2334 is done
# 2335 is running
# 2335 is done
# 2336 is running
# 2336 is done
# 2337 is running
# 2337 is done
# 2338 is running
# 2338 is done
# 2339 is running
# 2339 is done
# 2340 is running
# 2340 is done
# 2341 is running
# 2341 is done
# 2342 is running
# 2342 is done
# 2343 is running
# 2343 is done
# 2344 is running
# 2344 is done
# 2345 is running
# 2345 is done
# 2346 is running
# 2346 is done
# 2347 is running
# 2347 is done
# 2348 is running
# 2348 is done
# 2349 is running
# 2349 is done
# 2350 is running
# 2350 is done
# 2351 is running
# 2351 is done
# 2352 is running
# 2352 is done
# 2353 is running
# 2353 is done
# 2354 is running
# 2354 is done
# 2355 is running
# 2355 is done
# 2356 is running
# 2356 is done
# 2357 is running
# 2357 is done
# 2358 is running
# 2359 is running
# 2359 is done
# 2360 is running
# 2360 is done
# 2361 is running
# 2361 is done
# 2362 is running
# 2362 is done
# 2363 is running
# 2363 is done
# 2364 is running
# 2364 is done
# 2365 is running
# 2365 is done
# 2366 is running
# 2366 is done
# 2367 is running
# 2367 is done
# 2368 is running
# 2368 is done
# 2369 is running
# 2369 is done
# 2370 is running
# 2370 is done
# 2371 is running
# 2371 is done
# 2372 is running
# 2372 is done
# 2373 is running
# 2373 is done
# 2374 is running
# 2374 is done
# 2375 is running
# 2375 is done
# 2376 is running
# 2376 is done
# 2377 is running
# 2377 is done
# 2378 is running
# 2378 is done
# 2379 is running
# 2379 is done
# 2380 is running
# 2381 is running
# 2382 is running
# 2382 is done
# 2383 is running
# 2383 is done
# 2384 is running
# 2384 is done
# 2385 is running
# 2385 is done
# 2386 is running
# 2386 is done
# 2387 is running
# 2388 is running
# 2388 is done
# 2389 is running
# 2390 is running
# 2390 is done
# 2391 is running
# 2391 is done
# 2392 is running
# 2392 is done
# 2393 is running
# 2393 is done
# 2394 is running
# 2394 is done
# 2395 is running
# 2395 is done
# 2396 is running
# 2396 is done
# 2397 is running
# 2397 is done
# 2398 is running
# 2398 is done
# 2399 is running
# 2399 is done
# 2400 is running
# 2400 is done
# 2401 is running
# 2401 is done
# 2402 is running
# 2402 is done
# 2403 is running
# 2404 is running
# 2404 is done
# 2405 is running
# 2405 is done
# 2406 is running
# 2406 is done
# 2407 is running
# 2407 is done
# 2408 is running
# 2408 is done
# 2409 is running
# 2409 is done
# 2410 is running
# 2410 is done
# 2411 is running
# 2411 is done
# 2412 is running
# 2412 is done
# 2413 is running
# 2413 is done
# 2414 is running
# 2414 is done
# 2415 is running
# 2415 is done
# 2416 is running
# 2416 is done
# 2417 is running
# 2417 is done
# 2418 is running
# 2418 is done
# 2419 is running
# 2419 is done
# 2420 is running
# 2420 is done
# 2421 is running
# 2421 is done
# 2422 is running
# 2422 is done
# 2423 is running
# 2423 is done
# 2424 is running
# 2424 is done
# 2425 is running
# 2425 is done
# 2426 is running
# 2426 is done
# 2427 is running
# 2428 is running
# 2428 is done
# 2429 is running
# 2429 is done
# 2430 is running
# 2430 is done
# 2431 is running
# 2431 is done
# 2432 is running
# 2433 is running
# 2433 is done
# 2434 is running
# 2434 is done
# 2435 is running
# 2436 is running
# 2436 is done
# 2437 is running
# 2437 is done
# 2438 is running
# 2438 is done
# 2439 is running
# 2439 is done
# 2440 is running
# 2440 is done
# 2441 is running
# 2441 is done
# 2442 is running
# 2442 is done
# 2443 is running
# 2443 is done
# 2444 is running
# 2444 is done
# 2445 is running
# 2445 is done
# 2446 is running
# 2446 is done
# 2447 is running
# 2447 is done
# 2448 is running
# 2448 is done
# 2449 is running
# 2449 is done
# 2450 is running
# 2450 is done
# 2451 is running
# 2451 is done
# 2452 is running
# 2452 is done
# 2453 is running
# 2453 is done
# 2454 is running
# 2454 is done
# 2455 is running
# 2455 is done
# 2456 is running
# 2456 is done
# 2457 is running
# 2457 is done
# 2458 is running
# 2458 is done
# 2459 is running
# 2459 is done
# 2460 is running
# 2460 is done
# 2461 is running
# 2461 is done
# 2462 is running
# 2463 is running
# 2463 is done
# 2464 is running
# 2464 is done
# 2465 is running
# 2465 is done
# 2466 is running
# 2466 is done
# 2467 is running
# 2467 is done
# 2468 is running
# 2468 is done
# 2469 is running
# 2469 is done
# 2470 is running
# 2470 is done
# 2471 is running
# 2471 is done
# 2472 is running
# 2472 is done
# 2473 is running
# 2473 is done
# 2474 is running
# 2474 is done
# 2475 is running
# 2475 is done
# 2476 is running
# 2476 is done
# 2477 is running
# 2477 is done
# 2478 is running
# 2478 is done
# 2479 is running
# 2480 is running
# 2480 is done
# 2481 is running
# 2481 is done
# 2482 is running
# 2482 is done
# 2483 is running
# 2483 is done
# 2484 is running
# 2484 is done
# 2485 is running
# 2486 is running
# 2486 is done
# 2487 is running
# 2487 is done
# 2488 is running
# 2488 is done
# 2489 is running
# 2489 is done
# 2490 is running
# 2490 is done
# 2491 is running
# 2491 is done
# 2492 is running
# 2492 is done
# 2493 is running
# 2493 is done
# 2494 is running
# 2494 is done
# 2495 is running
# 2495 is done
# 2496 is running
# 2496 is done
# 2497 is running
# 2497 is done
# 2498 is running
# 2498 is done
# 2499 is running
# 2499 is done
# 2500 is running
# 2500 is done
# 2501 is running
# 2501 is done
# 2502 is running
# 2503 is running
# 2503 is done
# 2504 is running
# 2504 is done
# 2505 is running
# 2505 is done
# 2506 is running
# 2506 is done
# 2507 is running
# 2507 is done
# 2508 is running
# 2508 is done
# 2509 is running
# 2509 is done
# 2510 is running
# 2510 is done
# 2511 is running
# 2511 is done
# 2512 is running
# 2512 is done
# 2513 is running
# 2513 is done
# 2514 is running
# 2514 is done
# 2515 is running
# 2515 is done
# 2516 is running
# 2516 is done
# 2517 is running
# 2517 is done
# 2518 is running
# 2518 is done
# 2519 is running
# 2519 is done
# 2520 is running
# 2520 is done
# 2521 is running
# 2521 is done
# 2522 is running
# 2522 is done
# 2523 is running
# 2524 is running
# 2524 is done
# 2525 is running
# 2525 is done
# 2526 is running
# 2526 is done
# 2527 is running
# 2527 is done
# 2528 is running
# 2528 is done
# 2529 is running
# 2529 is done
# 2530 is running
# 2530 is done
# 2531 is running
# 2531 is done
# 2532 is running
# 2532 is done
# 2533 is running
# 2533 is done
# 2534 is running
# 2534 is done
# 2535 is running
# 2535 is done
# 2536 is running
# 2536 is done
# 2537 is running
# 2537 is done
# 2538 is running
# 2538 is done
# 2539 is running
# 2539 is done
# 2540 is running
# 2540 is done
# 2541 is running
# 2541 is done
# 2542 is running
# 2542 is done
# 2543 is running
# 2543 is done
# 2544 is running
# 2544 is done
# 2545 is running
# 2545 is done
# 2546 is running
# 2546 is done
# 2547 is running
# 2547 is done
# 2548 is running
# 2548 is done
# 2549 is running
# 2549 is done
# 2550 is running
# 2550 is done
# 2551 is running
# 2551 is done
# 2552 is running
# 2552 is done
# 2553 is running
# 2553 is done
# 2554 is running
# 2554 is done
# 2555 is running
# 2555 is done
# 2556 is running
# 2556 is done
# 2557 is running
# 2557 is done
# 2558 is running
# 2558 is done
# 2559 is running
# 2559 is done
# 2560 is running
# 2560 is done
# 2561 is running
# 2561 is done
# 2562 is running
# 2562 is done
# 2563 is running
# 2563 is done
# 2564 is running
# 2564 is done
# 2565 is running
# 2565 is done
# 2566 is running
# 2566 is done
# 2567 is running
# 2567 is done
# 2568 is running
# 2568 is done
# 2569 is running
# 2569 is done
# 2570 is running
# 2571 is running
# 2572 is running
# 2572 is done
# 2573 is running
# 2573 is done
# 2574 is running
# 2574 is done
# 2575 is running
# 2575 is done
# 2576 is running
# 2576 is done
# 2577 is running
# 2577 is done
# 2578 is running
# 2578 is done
# 2579 is running
# 2579 is done
# 2580 is running
# 2580 is done
# 2581 is running
# 2581 is done
# 2582 is running
# 2582 is done
# 2583 is running
# 2583 is done
# 2584 is running
# 2584 is done
# 2585 is running
# 2585 is done
# 2586 is running
# 2586 is done
# 2587 is running
# 2587 is done
# 2588 is running
# 2588 is done
# 2589 is running
# 2589 is done
# 2590 is running
# 2590 is done
# 2591 is running
# 2591 is done
# 2592 is running
# 2592 is done
# 2593 is running
# 2593 is done
# 2594 is running
# 2594 is done
# 2595 is running
# 2595 is done
# 2596 is running
# 2596 is done
# 2597 is running
# 2597 is done
# 2598 is running
# 2598 is done
# 2599 is running
# 2600 is running
# 2600 is done
# 2601 is running
# 2601 is done
# 2602 is running
# 2602 is done
# 2603 is running
# 2603 is done
# 2604 is running
# 2604 is done
# 2605 is running
# 2605 is done
# 2606 is running
# 2606 is done
# 2607 is running
# 2608 is running
# 2608 is done
# 2609 is running
# 2609 is done
# 2610 is running
# 2610 is done
# 2611 is running
# 2612 is running
# 2612 is done
# 2613 is running
# 2613 is done
# 2614 is running
# 2614 is done
# 2615 is running
# 2615 is done
# 2616 is running
# 2616 is done
# 2617 is running
# 2617 is done
# 2618 is running
# 2618 is done
# 2619 is running
# 2619 is done
# 2620 is running
# 2620 is done
# 2621 is running
# 2621 is done
# 2622 is running
# 2622 is done
# 2623 is running
# 2623 is done
# 2624 is running
# 2624 is done
# 2625 is running
# 2625 is done
# 2626 is running
# 2626 is done
# 2627 is running
# 2627 is done
# 2628 is running
# 2628 is done
# 2629 is running
# 2629 is done
# 2630 is running
# 2630 is done
# 2631 is running
# 2631 is done
# 2632 is running
# 2632 is done
# 2633 is running
# 2633 is done
# 2634 is running
# 2634 is done
# 2635 is running
# 2635 is done
# 2636 is running
# 2636 is done
# 2637 is running
# 2637 is done
# 2638 is running
# 2639 is running
# 2639 is done
# 2640 is running
# 2640 is done
# 2641 is running
# 2641 is done
# 2642 is running
# 2642 is done
# 2643 is running
# 2643 is done
# 2644 is running
# 2644 is done
# 2645 is running
# 2645 is done
# 2646 is running
# 2646 is done
# 2647 is running
# 2647 is done
# 2648 is running
# 2648 is done
# 2649 is running
# 2649 is done
# 2650 is running
# 2650 is done
# 2651 is running
# 2651 is done
# 2652 is running
# 2652 is done
# 2653 is running
# 2653 is done
# 2654 is running
# 2654 is done
# 2655 is running
# 2655 is done
# 2656 is running
# 2656 is done
# 2657 is running
# 2657 is done
# 2658 is running
# 2658 is done
# 2659 is running
# 2659 is done
# 2660 is running
# 2660 is done
# 2661 is running
# 2661 is done
# 2662 is running
# 2662 is done
# 2663 is running
# 2663 is done
# 2664 is running
# 2664 is done
# 2665 is running
# 2665 is done
# 2666 is running
# 2666 is done
# 2667 is running
# 2667 is done
# 2668 is running
# 2668 is done
# 2669 is running
# 2669 is done
# 2670 is running
# 2670 is done
# 2671 is running
# 2671 is done
# 2672 is running
# 2672 is done
# 2673 is running
# 2673 is done
# 2674 is running
# 2674 is done
# 2675 is running
# 2675 is done
# 2676 is running
# 2676 is done
# 2677 is running
# 2677 is done
# 2678 is running
# 2678 is done
# 2679 is running
# 2679 is done
# 2680 is running
# 2680 is done
# 2681 is running
# 2681 is done
# 2682 is running
# 2682 is done
# 2683 is running
# 2683 is done
# 2684 is running
# 2684 is done
# 2685 is running
# 2685 is done
# 2686 is running
# 2687 is running
# 2687 is done
# 2688 is running
# 2688 is done
# 2689 is running
# 2689 is done
# 2690 is running
# 2690 is done
# 2691 is running
# 2691 is done
# 2692 is running
# 2692 is done
# 2693 is running
# 2693 is done
# 2694 is running
# 2694 is done
# 2695 is running
# 2695 is done
# 2696 is running
# 2696 is done
# 2697 is running
# 2697 is done
# 2698 is running
# 2698 is done
# 2699 is running
# 2699 is done
# 2700 is running
# 2700 is done
# 2701 is running
# 2701 is done
# 2702 is running
# 2702 is done
# 2703 is running
# 2703 is done
# 2704 is running
# 2704 is done
# 2705 is running
# 2705 is done
# 2706 is running
# 2706 is done
# 2707 is running
# 2708 is running
# 2708 is done
# 2709 is running
# 2709 is done
# 2710 is running
# 2710 is done
# 2711 is running
# 2711 is done
# 2712 is running
# 2712 is done
# 2713 is running
# 2713 is done
# 2714 is running
# 2715 is running
# 2715 is done
# 2716 is running
# 2717 is running
# 2717 is done
# 2718 is running
# 2718 is done
# 2719 is running
# 2719 is done
# 2720 is running
# 2720 is done
# 2721 is running
# 2721 is done
# 2722 is running
# 2722 is done
# 2723 is running
# 2723 is done
# 2724 is running
# 2725 is running
# 2725 is done
# 2726 is running
# 2726 is done
# 2727 is running
# 2728 is running
# 2728 is done
# 2729 is running
# 2729 is done
# 2730 is running
# 2730 is done
# 2731 is running
# 2731 is done
# 2732 is running
# 2732 is done
# 2733 is running
# 2734 is running
# 2734 is done
# 2735 is running
# 2735 is done
# 2736 is running
# 2736 is done
# 2737 is running
# 2737 is done
# 2738 is running
# 2738 is done
# 2739 is running
# 2739 is done
# 2740 is running
# 2740 is done
# 2741 is running
# 2741 is done
# 2742 is running
# 2742 is done
# 2743 is running
# 2743 is done
# 2744 is running
# 2744 is done
# 2745 is running
# 2745 is done
# 2746 is running
# 2746 is done
# 2747 is running
# 2748 is running
# 2748 is done
# 2749 is running
# 2749 is done
# 2750 is running
# 2750 is done
# 2751 is running
# 2751 is done
# 2752 is running
# 2752 is done
# 2753 is running
# 2753 is done
# 2754 is running
# 2755 is running
# 2755 is done
# 2756 is running
# 2756 is done
# 2757 is running
# 2758 is running
# 2758 is done
# 2759 is running
# 2759 is done
# 2760 is running
# 2760 is done
# 2761 is running
# 2761 is done
# 2762 is running
# 2763 is running
# 2763 is done
# 2764 is running
# 2764 is done
# 2765 is running
# 2765 is done
# 2766 is running
# 2766 is done
# 2767 is running
# 2767 is done
# 2768 is running
# 2768 is done
# 2769 is running
# 2769 is done
# 2770 is running
# 2771 is running
# 2771 is done
# 2772 is running
# 2773 is running
# 2773 is done
# 2774 is running
# 2774 is done
# 2775 is running
# 2775 is done
# 2776 is running
# 2776 is done
# 2777 is running
# 2777 is done
# 2778 is running
# 2778 is done
# 2779 is running
# 2779 is done
# 2780 is running
# 2780 is done
# 2781 is running
# 2781 is done
# 2782 is running
# 2782 is done
# 2783 is running
# 2783 is done
# 2784 is running
# 2784 is done
# 2785 is running
# 2785 is done
# 2786 is running
# 2786 is done
# 2787 is running
# 2787 is done
# 2788 is running
# 2788 is done
# 2789 is running
# 2789 is done
# 2790 is running
# 2790 is done
# 2791 is running
# 2791 is done
# 2792 is running
# 2792 is done
# 2793 is running
# 2793 is done
# 2794 is running
# 2794 is done
# 2795 is running
# 2795 is done
# 2796 is running
# 2796 is done
# 2797 is running
# 2797 is done
# 2798 is running
# 2798 is done
# 2799 is running
# 2799 is done
# 2800 is running
# 2800 is done
# 2801 is running
# 2802 is running
# 2802 is done
# 2803 is running
# 2803 is done
# 2804 is running
# 2804 is done
# 2805 is running
# 2805 is done
# 2806 is running
# 2806 is done
# 2807 is running
# 2807 is done
# 2808 is running
# 2808 is done
# 2809 is running
# 2809 is done
# 2810 is running
# 2810 is done
# 2811 is running
# 2811 is done
# 2812 is running
# 2812 is done
# 2813 is running
# 2813 is done
# 2814 is running
# 2814 is done
# 2815 is running
# 2815 is done
# 2816 is running
# 2816 is done
# 2817 is running
# 2817 is done
# 2818 is running
# 2818 is done
# 2819 is running
# 2819 is done
# 2820 is running
# 2820 is done
# 2821 is running
# 2822 is running
# 2822 is done
# 2823 is running
# 2823 is done
# 2824 is running
# 2824 is done
# 2825 is running
# 2825 is done
# 2826 is running
# 2826 is done
# 2827 is running
# 2827 is done
# 2828 is running
# 2828 is done
# 2829 is running
# 2829 is done
# 2830 is running
# 2830 is done
# 2831 is running
# 2832 is running
# 2832 is done
# 2833 is running
# 2833 is done
# 2834 is running
# 2834 is done
# 2835 is running
# 2835 is done
# 2836 is running
# 2837 is running
# 2837 is done
# 2838 is running
# 2838 is done
# 2839 is running
# 2839 is done
# 2840 is running
# 2840 is done
# 2841 is running
# 2841 is done
# 2842 is running
# 2842 is done
# 2843 is running
# 2843 is done
# 2844 is running
# 2844 is done
# 2845 is running
# 2845 is done
# 2846 is running
# 2847 is running
# 2847 is done
# 2848 is running
# 2848 is done
# 2849 is running
# 2849 is done
# 2850 is running
# 2850 is done
# 2851 is running
# 2851 is done
# 2852 is running
# 2853 is running
# 2853 is done
# 2854 is running
# 2855 is running
# 2856 is running
# 2856 is done
# 2857 is running
# 2857 is done
# 2858 is running
# 2858 is done
# 2859 is running
# 2859 is done
# 2860 is running
# 2860 is done
# 2861 is running
# 2861 is done
# 2862 is running
# 2863 is running
# 2863 is done
# 2864 is running
# 2864 is done
# 2865 is running
# 2866 is running
# 2866 is done
# 2867 is running
# 2867 is done
# 2868 is running
# 2868 is done
# 2869 is running
# 2869 is done
# 2870 is running
# 2870 is done
# 2871 is running
# 2871 is done
# 2872 is running
# 2872 is done
# 2873 is running
# 2873 is done
# 2874 is running
# 2875 is running
# 2875 is done
# 2876 is running
# 2876 is done
# 2877 is running
# 2877 is done
# 2878 is running
# 2879 is running
# 2879 is done
# 2880 is running
# 2881 is running
# 2881 is done
# 2882 is running
# 2882 is done
# 2883 is running
# 2883 is done
# 2884 is running
# 2884 is done
# 2885 is running
# 2885 is done
# 2886 is running
# 2886 is done
# 2887 is running
# 2887 is done
# 2888 is running
# 2888 is done
# 2889 is running
# 2889 is done
# 2890 is running
# 2890 is done
# 2891 is running
# 2891 is done
# 2892 is running
# 2892 is done
# 2893 is running
# 2893 is done
# 2894 is running
# 2894 is done
# 2895 is running
# 2895 is done
# 2896 is running
# 2896 is done
# 2897 is running
# 2897 is done
# 2898 is running
# 2899 is running
# 2899 is done
# 2900 is running
# 2900 is done
# 2901 is running
# 2901 is done
# 2902 is running
# 2902 is done
# 2903 is running
# 2903 is done
# 2904 is running
# 2904 is done
# 2905 is running
# 2905 is done
# 2906 is running
# 2906 is done
# 2907 is running
# 2907 is done
# 2908 is running
# 2908 is done
# 2909 is running
# 2909 is done
# 2910 is running
# 2910 is done
# 2911 is running
# 2911 is done
# 2912 is running
# 2912 is done
# 2913 is running
# 2913 is done
# 2914 is running
# 2914 is done
# 2915 is running
# 2915 is done
# 2916 is running
# 2916 is done
# 2917 is running
# 2917 is done
# 2918 is running
# 2918 is done
# 2919 is running
# 2919 is done
# 2920 is running
# 2920 is done
# 2921 is running
# 2921 is done
# 2922 is running
# 2922 is done
# 2923 is running
# 2923 is done
# 2924 is running
# 2924 is done
# 2925 is running
# 2925 is done
# 2926 is running
# 2926 is done
# 2927 is running
# 2927 is done
# 2928 is running
# 2928 is done
# 2929 is running
# 2929 is done
# 2930 is running
# 2930 is done
# 2931 is running
# 2931 is done
# 2932 is running
# 2932 is done
# 2933 is running
# 2933 is done
# 2934 is running
# 2934 is done
# 2935 is running
# 2935 is done
# 2936 is running
# 2936 is done
# 2937 is running
# 2937 is done
# 2938 is running
# 2938 is done
# 2939 is running
# 2940 is running
# 2940 is done
# 2941 is running
# 2942 is running
# 2942 is done
# 2943 is running
# 2943 is done
# 2944 is running
# 2944 is done
# 2945 is running
# 2945 is done
# 2946 is running
# 2946 is done
# 2947 is running
# 2947 is done
# 2948 is running
# 2948 is done
# 2949 is running
# 2949 is done
# 2950 is running
# 2950 is done
# 2951 is running
# 2951 is done
# 2952 is running
# 2952 is done
# 2953 is running
# 2953 is done
# 2954 is running
# 2954 is done
# 2955 is running
# 2955 is done
# 2956 is running
# 2957 is running
# 2957 is done
# 2958 is running
# 2958 is done
# 2959 is running
# 2959 is done
# 2960 is running
# 2960 is done
# 2961 is running
# 2961 is done
# ...
# 4844 is done
# 4845 is running
# 4845 is done
# 4846 is running
# 4846 is done
# 4847 is running
# 4847 is done
# 4848 is running
# 4848 is done
# 4849 is running
# 4849 is done
# 4850 is running
# 4850 is done
# 4851 is running
# 4851 is done
# 4852 is running
# 4852 is done
# 4853 is running
# 4853 is done
# 4854 is running
# 4854 is done
# 4855 is running
# 4855 is done
# 4856 is running
# 4856 is done
# 4857 is running
# 4857 is done
# 4858 is running
# 4858 is done
# 4859 is running
# 4859 is done
# 4860 is running
# 4860 is done
# 4861 is running
# 4861 is done
# 4862 is running
# 4862 is done
# 4863 is running
# 4863 is done
# 4864 is running
# 4864 is done
# 4865 is running
# 4865 is done
# 4866 is running
# 4866 is done
# 4867 is running
# 4867 is done
# 4868 is running
# 4868 is done
# 4869 is running
# 4869 is done
# 4870 is running
# 4870 is done
# 4871 is running
# 4871 is done
# 4872 is running
# 4872 is done
# 4873 is running
# 4873 is done
# 4874 is running
# 4874 is done
# 4875 is running
# 4875 is done
# 4876 is running
# 4876 is done
# 4877 is running
# 4877 is done
# 4878 is running
# 4878 is done
# 4879 is running
# 4879 is done
# 4880 is running
# 4880 is done
# 4881 is running
# 4881 is done
# 4882 is running
# 4883 is running
# 4883 is done
# 4884 is running
# 4884 is done
# 4885 is running
# 4885 is done
# 4886 is running
# 4886 is done
# 4887 is running
# 4887 is done
# 4888 is running
# 4888 is done
# 4889 is running
# 4889 is done
# 4890 is running
# 4890 is done
# 4891 is running
# 4891 is done
# 4892 is running
# 4892 is done
# 4893 is running
# 4893 is done
# 4894 is running
# 4894 is done
# 4895 is running
# 4895 is done
# 4896 is running
# 4896 is done
# 4897 is running
# 4897 is done
# 4898 is running
# 4898 is done
# 4899 is running
# 4899 is done
# 4900 is running
# 4900 is done
# 4901 is running
# 4901 is done
# 4902 is running
# 4902 is done
# 4903 is running
# 4903 is done
# 4904 is running
# 4904 is done
# 4905 is running
# 4905 is done
# 4906 is running
# 4906 is done
# 4907 is running
# 4908 is running
# 4908 is done
# 4909 is running
# 4909 is done
# 4910 is running
# 4910 is done
# 4911 is running
# 4911 is done
# 4912 is running
# 4912 is done
# 4913 is running
# 4913 is done
# 4914 is running
# 4914 is done
# 4915 is running
# 4915 is done
# 4916 is running
# 4916 is done
# 4917 is running
# 4917 is done
# 4918 is running
# 4918 is done
# 4919 is running
# 4919 is done
# 4920 is running
# 4920 is done
# 4921 is running
# 4921 is done
# 4922 is running
# 4922 is done
# 4923 is running
# 4923 is done
# 4924 is running
# 4924 is done
# 4925 is running
# 4925 is done
# 4926 is running
# 4926 is done
# 4927 is running
# 4927 is done
# 4928 is running
# 4928 is done
# 4929 is running
# 4929 is done
# 4930 is running
# 4930 is done
# 4931 is running
# 4931 is done
# 4932 is running
# 4932 is done
# 4933 is running
# 4933 is done
# 4934 is running
# 4934 is done
# 4935 is running
# 4935 is done
# 4936 is running
# 4936 is done
# 4937 is running
# 4937 is done
# 4938 is running
# 4938 is done
# 4939 is running
# 4939 is done
# 4940 is running
# 4940 is done
# 4941 is running
# 4941 is done
# 4942 is running
# 4942 is done
# 4943 is running
# 4943 is done
# 4944 is running
# 4944 is done
# 4945 is running
# 4945 is done
# 4946 is running
# 4946 is done
# 4947 is running
# 4947 is done
# 4948 is running
# 4948 is done
# 4949 is running
# 4949 is done
# 4950 is running
# 4950 is done
# 4951 is running
# 4951 is done
# 4952 is running
# 4952 is done
# 4953 is running
# 4953 is done
# 4954 is running
# 4954 is done
# 4955 is running
# 4955 is done
# 4956 is running
# 4956 is done
# 4957 is running
# 4958 is running
# 4958 is done
# 4959 is running
# 4959 is done
# 4960 is running
# 4960 is done
# 4961 is running
# 4961 is done
# 4962 is running
# 4962 is done
# 4963 is running
# 4963 is done
# 4964 is running
# 4964 is done
# 4965 is running
# 4965 is done
# 4966 is running
# 4966 is done
# 4967 is running
# 4967 is done
# 4968 is running
# 4968 is done
# 4969 is running
# 4969 is done
# 4970 is running
# 4970 is done
# 4971 is running
# 4971 is done
# 4972 is running
# 4972 is done
# 4973 is running
# 4973 is done
# 4974 is running
# 4974 is done
# 4975 is running
# 4975 is done
# 4976 is running
# 4976 is done
# 4977 is running
# 4977 is done
# 4978 is running
# 4978 is done
# 4979 is running
# 4979 is done
# 4980 is running
# 4980 is done
# 4981 is running
# 4981 is done
# 4982 is running
# 4982 is done
# 4983 is running
# 4983 is done
# 4984 is running
# 4984 is done
# 4985 is running
# 4985 is done
# 4986 is running
# 4986 is done
# 4987 is running
# 4987 is done
# 4988 is running
# 4988 is done
# 4989 is running
# 4989 is done
# 4990 is running
# 4990 is done
# 4991 is running
# 4991 is done
# 4992 is running
# 4992 is done
# 4993 is running
# 4993 is done
# 4994 is running
# 4994 is done
# 4995 is running
# 4995 is done
# 4996 is running
# 4996 is done
# 4997 is running
# 4997 is done
# 4998 is running
# 4998 is done
# 4999 is running
# 4999 is done
# 5000 is running
# 5000 is done
# 5001 is running
# 5001 is done
# 5002 is running
# 5002 is done
# 5003 is running
# 5003 is done
# 5004 is running
# 5004 is done
# 5005 is running
# 5005 is done
# 5006 is running
# 5006 is done
# 5007 is running
# 5007 is done
# 5008 is running
# 5008 is done
# 5009 is running
# 5009 is done
# 5010 is running
# 5010 is done
# 5011 is running
# 5011 is done
# 5012 is running
# 5012 is done
# 5013 is running
# 5013 is done
# 5014 is running
# 5014 is done
# 5015 is running
# 5015 is done
# 5016 is running
# 5016 is done
# 5017 is running
# 5017 is done
# 5018 is running
# 5018 is done
# 5019 is running
# 5019 is done
# 5020 is running
# 5020 is done
# 5021 is running
# 5021 is done
# 5022 is running
# 5022 is done
# 5023 is running
# 5023 is done
# 5024 is running
# 5024 is done
# 5025 is running
# 5025 is done
# 5026 is running
# 5026 is done
# 5027 is running
# 5027 is done
# 5028 is running
# 5028 is done
# 5029 is running
# 5029 is done
# 5030 is running
# 5030 is done
# 5031 is running
# 5031 is done
# 5032 is running
# 5032 is done
# 5033 is running
# 5033 is done
# 5034 is running
# 5034 is done
# 5035 is running
# 5035 is done
# 5036 is running
# 5036 is done
# 5037 is running
# 5037 is done
# 5038 is running
# 5038 is done
# 5039 is running
# 5039 is done
# 5040 is running
# 5040 is done
# 5041 is running
# 5041 is done
# 5042 is running
# 5042 is done
# 5043 is running
# 5043 is done
# 5044 is running
# 5044 is done
# 5045 is running
# 5045 is done
# 5046 is running
# 5046 is done
# 5047 is running
# 5047 is done
# 5048 is running
# 5048 is done
# 5049 is running
# 5049 is done
# 5050 is running
# 5050 is done
# 5051 is running
# 5051 is done
# 5052 is running
# 5052 is done
# 5053 is running
# 5053 is done
# 5054 is running
# 5054 is done
# 5055 is running
# 5055 is done
# 5056 is running
# 5056 is done
# 5057 is running
# 5057 is done
# 5058 is running
# 5058 is done
# 5059 is running
# 5059 is done
# 5060 is running
# 5060 is done
# 5061 is running
# 5061 is done
# 5062 is running
# 5062 is done
# 5063 is running
# 5063 is done
# 5064 is running
# 5064 is done
# 5065 is running
# 5065 is done
# 5066 is running
# 5066 is done
# 5067 is running
# 5067 is done
# 5068 is running
# 5068 is done
# 5069 is running
# 5069 is done
# 5070 is running
# 5070 is done
# 5071 is running
# 5071 is done
# 5072 is running
# 5072 is done
# 5073 is running
# 5073 is done
# 5074 is running
# 5074 is done
# 5075 is running
# 5075 is done
# 5076 is running
# 5076 is done
# 5077 is running
# 5077 is done
# 5078 is running
# 5078 is done
# 5079 is running
# 5079 is done
# 5080 is running
# 5080 is done
# 5081 is running
# 5081 is done
# 5082 is running
# 5082 is done
# 5083 is running
# 5083 is done
# 5084 is running
# 5084 is done
# 5085 is running
# 5085 is done
# 5086 is running
# 5086 is done
# 5087 is running
# 5087 is done
# 5088 is running
# 5088 is done
# 5089 is running
# 5089 is done
# 5090 is running
# 5090 is done
# 5091 is running
# 5091 is done
# 5092 is running
# 5092 is done
# 5093 is running
# 5093 is done
# 5094 is running
# 5094 is done
# 5095 is running
# 5095 is done
# 5096 is running
# 5096 is done
# 5097 is running
# 5097 is done
# 5098 is running
# 5098 is done
# 5099 is running
# 5099 is done
# 5100 is running
# 5100 is done
# 5101 is running
# 5101 is done
# 5102 is running
# 5102 is done
# 5103 is running
# 5103 is done
# 5104 is running
# 5104 is done
# 5105 is running
# 5105 is done
# 5106 is running
# 5106 is done
# 5107 is running
# 5107 is done
# 5108 is running
# 5108 is done
# 5109 is running
# 5109 is done
# 5110 is running
# 5110 is done
# 5111 is running
# 5111 is done
# 5112 is running
# 5112 is done
# 5113 is running
# 5113 is done
# 5114 is running
# 5114 is done
# 5115 is running
# 5115 is done
# 5116 is running
# 5116 is done
# 5117 is running
# 5117 is done
# 5118 is running
# 5118 is done
# 5119 is running
# 5119 is done
# 5120 is running
# 5120 is done
# 5121 is running
# 5121 is done
# 5122 is running
# 5122 is done
# 5123 is running
# 5123 is done
# 5124 is running
# 5124 is done
# 5125 is running
# 5125 is done
# 5126 is running
# 5126 is done
# 5127 is running
# 5127 is done
# 5128 is running
# 5128 is done
# 5129 is running
# 5129 is done
# 5130 is running
# 5130 is done
# 5131 is running
# 5131 is done
# 5132 is running
# 5132 is done
# 5133 is running
# 5133 is done
# 5134 is running
# 5134 is done
# 5135 is running
# 5135 is done
# 5136 is running
# 5136 is done
# 5137 is running
# 5137 is done
# 5138 is running
# 5138 is done
# 5139 is running
# 5139 is done
# 5140 is running
# 5140 is done
# 5141 is running
# 5141 is done
# 5142 is running
# 5142 is done
# 5143 is running
# 5143 is done
# 5144 is running
# 5144 is done
# 5145 is running
# 5145 is done
# 5146 is running
# 5146 is done
# 5147 is running
# 5147 is done
# 5148 is running
# 5148 is done
# 5149 is running
# 5149 is done
# 5150 is running
# 5150 is done
# 5151 is running
# 5151 is done
# 5152 is running
# 5152 is done
# 5153 is running
# 5153 is done
# 5154 is running
# 5154 is done
# 5155 is running
# 5155 is done
# 5156 is running
# 5156 is done
# 5157 is running
# 5157 is done
# 5158 is running
# 5158 is done
# 5159 is running
# 5159 is done
# 5160 is running
# 5160 is done
# 5161 is running
# 5161 is done
# 5162 is running
# 5162 is done
# 5163 is running
# 5163 is done
# 5164 is running
# 5164 is done
# 5165 is running
# 5165 is done
# 5166 is running
# 5166 is done
# 5167 is running
# 5167 is done
# 5168 is running
# 5168 is done
# 5169 is running
# 5169 is done
# 5170 is running
# 5170 is done
# 5171 is running
# 5171 is done
# 5172 is running
# 5172 is done
# 5173 is running
# 5173 is done
# 5174 is running
# 5174 is done
# 5175 is running
# 5175 is done
# 5176 is running
# 5176 is done
# 5177 is running
# 5177 is done
# 5178 is running
# 5178 is done
# 5179 is running
# 5179 is done
# 5180 is running
# 5180 is done
# 5181 is running
# 5181 is done
# 5182 is running
# 5182 is done
# 5183 is running
# 5183 is done
# 5184 is running
# 5184 is done
# 5185 is running
# 5185 is done
# 5186 is running
# 5186 is done
# 5187 is running
# 5187 is done
# 5188 is running
# 5188 is done
# 5189 is running
# 5189 is done
# 5190 is running
# 5190 is done
# 5191 is running
# 5191 is done
# 5192 is running
# 5192 is done
# 5193 is running
# 5193 is done
# 5194 is running
# 5194 is done
# 5195 is running
# 5195 is done
# 5196 is running
# 5196 is done
# 5197 is running
# 5197 is done
# 5198 is running
# 5198 is done
# 5199 is running
# 5199 is done
# 5200 is running
# 5200 is done
# 5201 is running
# 5201 is done
# 5202 is running
# 5203 is running
# 5203 is done
# 5204 is running
# 5204 is done
# 5205 is running
# 5205 is done
# 5206 is running
# 5206 is done
# 5207 is running
# 5207 is done
# 5208 is running
# 5208 is done
# 5209 is running
# 5209 is done
# 5210 is running
# 5210 is done
# 5211 is running
# 5211 is done
# 5212 is running
# 5212 is done
# 5213 is running
# 5213 is done
# 5214 is running
# 5214 is done
# 5215 is running
# 5215 is done
# 5216 is running
# 5216 is done
# 5217 is running
# 5217 is done
# 5218 is running
# 5218 is done
# 5219 is running
# 5219 is done
# 5220 is running
# 5220 is done
# 5221 is running
# 5221 is done
# 5222 is running
# 5222 is done
# 5223 is running
# 5223 is done
# 5224 is running
# 5224 is done
# 5225 is running
# 5225 is done
# 5226 is running
# 5226 is done
# 5227 is running
# 5227 is done
# 5228 is running
# 5228 is done
# 5229 is running
# 5229 is done
# 5230 is running
# 5230 is done
# 5231 is running
# 5231 is done
# 5232 is running
# 5232 is done
# 5233 is running
# 5233 is done
# 5234 is running
# 5234 is done
# 5235 is running
# 5236 is running
# 5236 is done
# 5237 is running
# 5237 is done
# 5238 is running
# 5238 is done
# 5239 is running
# 5239 is done
# 5240 is running
# 5240 is done
# 5241 is running
# 5241 is done
# 5242 is running
# 5242 is done
# 5243 is running
# 5243 is done
# 5244 is running
# 5244 is done
# 5245 is running
# 5245 is done
# 5246 is running
# 5246 is done
# 5247 is running
# 5247 is done
# 5248 is running
# 5248 is done
# 5249 is running
# 5249 is done
# 5250 is running
# 5250 is done
# 5251 is running
# 5251 is done
# 5252 is running
# 5252 is done
# 5253 is running
# 5253 is done
# 5254 is running
# 5254 is done
# 5255 is running
# 5255 is done
# 5256 is running
# 5256 is done
# 5257 is running
# 5257 is done
# 5258 is running
# 5258 is done
# 5259 is running
# 5259 is done
# 5260 is running
# 5260 is done
# 5261 is running
# 5261 is done
# 5262 is running
# 5262 is done
# 5263 is running
# 5263 is done
# 5264 is running
# 5264 is done
# 5265 is running
# 5265 is done
# 5266 is running
# 5266 is done
# 5267 is running
# 5267 is done
# 5268 is running
# 5268 is done
# 5269 is running
# 5269 is done
# 5270 is running
# 5270 is done
# 5271 is running
# 5271 is done
# 5272 is running
# 5272 is done
# 5273 is running
# 5273 is done
# 5274 is running
# 5274 is done
# 5275 is running
# 5275 is done
# 5276 is running
# 5276 is done
# 5277 is running
# 5277 is done
# 5278 is running
# 5278 is done
# 5279 is running
# 5279 is done
# 5280 is running
# 5280 is done
# 5281 is running
# 5281 is done
# 5282 is running
# 5282 is done
# 5283 is running
# 5283 is done
# 5284 is running
# 5284 is done
# 5285 is running
# 5285 is done
# 5286 is running
# 5286 is done
# 5287 is running
# 5287 is done
# 5288 is running
# 5288 is done
# 5289 is running
# 5289 is done
# 5290 is running
# 5290 is done
# 5291 is running
# 5291 is done
# 5292 is running
# 5292 is done
# 5293 is running
# 5293 is done
# 5294 is running
# 5294 is done
# 5295 is running
# 5295 is done
# 5296 is running
# 5296 is done
# 5297 is running
# 5297 is done
# 5298 is running
# 5298 is done
# 5299 is running
# 5299 is done
# 5300 is running
# 5300 is done
# 5301 is running
# 5301 is done
# 5302 is running
# 5302 is done
# 5303 is running
# 5303 is done
# 5304 is running
# 5304 is done
# 5305 is running
# 5305 is done
# 5306 is running
# 5306 is done
# 5307 is running
# 5307 is done
# 5308 is running
# 5308 is done
# 5309 is running
# 5309 is done
# 5310 is running
# 5310 is done
# 5311 is running
# 5311 is done
# 5312 is running
# 5312 is done
# 5313 is running
# 5313 is done
# 5314 is running
# 5314 is done
# 5315 is running
# 5315 is done
# 5316 is running
# 5316 is done
# 5317 is running
# 5317 is done
# 5318 is running
# 5318 is done
# 5319 is running
# 5319 is done
# 5320 is running
# 5320 is done
# 5321 is running
# 5321 is done
# 5322 is running
# 5322 is done
# 5323 is running
# 5323 is done
# 5324 is running
# 5324 is done
# 5325 is running
# 5325 is done
# 5326 is running
# 5326 is done
# 5327 is running
# 5327 is done
# 5328 is running
# 5328 is done
# 5329 is running
# 5329 is done
# 5330 is running
# 5330 is done
# 5331 is running
# 5331 is done
# 5332 is running
# 5332 is done
# 5333 is running
# 5333 is done
# 5334 is running
# 5334 is done
# 5335 is running
# 5335 is done
# 5336 is running
# 5337 is running
# 5337 is done
# 5338 is running
# 5338 is done
# 5339 is running
# 5339 is done
# 5340 is running
# 5340 is done
# 5341 is running
# 5341 is done
# 5342 is running
# 5343 is running
# 5343 is done
# 5344 is running
# 5344 is done
# 5345 is running
# 5345 is done
# 5346 is running
# 5346 is done
# 5347 is running
# 5347 is done
# 5348 is running
# 5348 is done
# 5349 is running
# 5349 is done
# 5350 is running
# 5350 is done
# 5351 is running
# 5351 is done
# 5352 is running
# 5352 is done
# 5353 is running
# 5353 is done
# 5354 is running
# 5354 is done
# 5355 is running
# 5355 is done
# 5356 is running
# 5357 is running
# 5357 is done
# 5358 is running
# 5358 is done
# 5359 is running
# 5359 is done
# 5360 is running
# 5360 is done
# 5361 is running
# 5361 is done
# 5362 is running
# 5362 is done
# 5363 is running
# 5363 is done
# 5364 is running
# 5364 is done
# 5365 is running
# 5365 is done
# 5366 is running
# 5366 is done
# 5367 is running
# 5367 is done
# 5368 is running
# 5368 is done
# 5369 is running
# 5369 is done
# 5370 is running
# 5370 is done
# 5371 is running
# 5371 is done
# 5372 is running
# 5372 is done
# 5373 is running
# 5373 is done
# 5374 is running
# 5374 is done
# 5375 is running
# 5375 is done
# 5376 is running
# 5376 is done
# 5377 is running
# 5377 is done
# 5378 is running
# 5378 is done
# 5379 is running
# 5379 is done
# 5380 is running
# 5380 is done
# 5381 is running
# 5381 is done
# 5382 is running
# 5382 is done
# 5383 is running
# 5383 is done
# 5384 is running
# 5384 is done
# 5385 is running
# 5385 is done
# 5386 is running
# 5386 is done
# 5387 is running
# 5387 is done
# 5388 is running
# 5388 is done
# 5389 is running
# 5389 is done
# 5390 is running
# 5390 is done
# 5391 is running
# 5391 is done
# 5392 is running
# 5392 is done
# 5393 is running
# 5393 is done
# 5394 is running
# 5394 is done
# 5395 is running
# 5395 is done
# 5396 is running
# 5396 is done
# 5397 is running
# 5397 is done
# 5398 is running
# 5398 is done
# 5399 is running

# %%
e_df = pd.DataFrame(errors)
e_df.to_csv('errors.csv')
